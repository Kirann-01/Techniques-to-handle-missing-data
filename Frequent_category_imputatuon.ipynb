# %% [markdown]
# #### FREQUENT CATEGORY IMPUTATION

# %%
import pandas as pd
df=pd.read_csv('train.csv',usecols=['BsmtQual','FireplaceQu','GarageType','SalePrice'])
df.head()
# Out:
#   BsmtQual FireplaceQu GarageType  SalePrice
# 0       Gd         NaN     Attchd     208500
# 1       Gd          TA     Attchd     181500
# 2       Gd          TA     Attchd     223500
# 3       TA          Gd     Detchd     140000
# 4       Gd          TA     Attchd     250000

# %%
df.isnull().sum()
# Out:
# BsmtQual        37
# FireplaceQu    690
# GarageType      81
# SalePrice        0
# dtype: int64

# %%
#Sorting the missing values
df.isnull().mean().sort_values(ascending=True)
# Out:
# SalePrice      0.000000
# BsmtQual       0.025342
# GarageType     0.055479
# FireplaceQu    0.472603
# dtype: float64

# %% [markdown]
# #### Compute frequency with every feature

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['BsmtQual'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['GarageType'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['FireplaceQu'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Gives the hidhest value holding category(This is an example for the function)
df['GarageType'].value_counts().index[0]
#Or we can use this too
df['GarageType'].mode()[0]
# Out:
# 'Attchd'

# %%
#Replacing function
def impute_nan(df,variable):
    most_frequent_category = df[variable].value_counts().index[0]
    df[variable].fillna(most_frequent_category,inplace=True)

# %%
for feature in ['BsmtQual','FireplaceQu','GarageType']:
    impute_nan(df,feature)

# %%
#Each and every missing value in a feature is replaced by most frequent value pf the same feature
df.isnull().sum()
# Out:
# BsmtQual       0
# FireplaceQu    0
# GarageType     0
# SalePrice      0
# dtype: int64
